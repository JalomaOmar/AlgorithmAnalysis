# %%
def Hanoi(n,src, dest, tmp): #Ésta es la función 
    if n>0:
        Hanoi(n-1, src, tmp, dest)
        src.pop() #En estas dos líneas se lleva a cabo el movimiento del disco, es decir, se saca de una lista (palo) para llevarlo al otro
        dest.append(n)
        input() #El input es para poder ver el proceso paso a paso de los movimientos de un palo a otro (lo utilicé en analogía con "getchar()" de C); recomiendo sólo presionar "enter".
        print(a) #Se están imprimiendo las listas "a", "b", "c"; ya que al imprimir "src", "tmp" y "dest", por la implementación recursiva al visualizar; parecía que movíamos los palos y se veía medio feo; los invito a cambiar "a" por "src", "b" por "tmp" y "c" por "dest" en esta parte del código (sólo en esta parte) para que vean a lo que me refiero.
        print(b)
        print(c)
        Hanoi(n-1, tmp, dest, src)

print("De cuantos disccos desea sus torres de Hanoi?") #Aquí se le pide al usuario el número de discos
N=int(input())
src=[i+1 for i in range(N)] #formamos un vector de 1 a N y lo ponemos al revés (estos serían los discos de menor a mayor y al ponerlos al revés de mayor a menor, como es que lo dicta el juego), para que en la visualización tengamos un sentido direccional del juego, esto es; hacemos que la "gravedad" vaya en esta dirección <-----
src.reverse()
dest=[] #Al inicio el "palo" destino está vacío
tmp=[] #Al inicio el "palo" de enmedio también está vacío
a=src #Aquí es donde se utilizan "a", "b" y "c" para poder visualizar las etapas del proceso de manera ordenada
b=tmp
c=dest
Hanoi(N, src, dest, tmp) #Se llama a la función y comenzamos a "jugar".
# Out:
# De cuantos disccos desea sus torres de Hanoi?
# 5
#
# [5, 4, 3, 2]
# []
# [1]
#
# [5, 4, 3]
# [2]
# [1]
# h
# [5, 4, 3]
# [2, 1]
# []
#
# [5, 4]
# [2, 1]
# [3]
#
# [5, 4, 1]
# [2]
# [3]
#
# [5, 4, 1]
# []
# [3, 2]
#
# [5, 4]
# []
# [3, 2, 1]
#
# [5]
# [4]
# [3, 2, 1]
#
# [5]
# [4, 1]
# [3, 2]
#
# [5, 2]
# [4, 1]
# [3]
#
# [5, 2, 1]
# [4]
# [3]
#
# [5, 2, 1]
# [4, 3]
# []
#
# [5, 2]
# [4, 3]
# [1]
#
# [5]
# [4, 3, 2]
# [1]
#
# [5]
# [4, 3, 2, 1]
# []
#
# []
# [4, 3, 2, 1]
# [5]
#
# [1]
# [4, 3, 2]
# [5]
#
# [1]
# [4, 3]
# [5, 2]
#
# []
# [4, 3]
# [5, 2, 1]
#
# [3]
# [4]
# [5, 2, 1]
#
# [3]
# [4, 1]
# [5, 2]
#
# [3, 2]
# [4, 1]
# [5]
#
# [3, 2, 1]
# [4]
# [5]
#
# [3, 2, 1]
# []
# [5, 4]
#
# [3, 2]
# []
# [5, 4, 1]
#
# [3]
# [2]
# [5, 4, 1]
#
# [3]
# [2, 1]
# [5, 4]
#
# []
# [2, 1]
# [5, 4, 3]
#
# [1]
# [2]
# [5, 4, 3]
#
# [1]
# []
# [5, 4, 3, 2]
#
# []
# []
# [5, 4, 3, 2, 1]
